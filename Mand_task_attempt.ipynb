# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load data
df = pd.read_csv('2017-1.xls')

df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
nCluster = 3

# %% [markdown]
# cluster countries into distinct groups based on their economic and social factors

# %%
socEconCol = ['Economy..GDP.per.Capita.', 'Family', 'Freedom', 'Generosity', 'Trust..Government.Corruption.', 'Dystopia.Residual']

# %%
socEconX = StandardScaler().fit_transform(df[socEconCol])

# %%
kMeansSocEcon = KMeans(n_clusters=nCluster, random_state=0)
kMeansSocEcon.fit(socEconX)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
nrRows = 5
figLength = nrRows*5

plt.figure(figsize=(10, figLength))

plt.subplot(nrRows,3,1)
plt.scatter(socEconX[:,0],socEconX[:,1] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,2)
plt.scatter(socEconX[:,0],socEconX[:,2] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,3)
plt.scatter(socEconX[:,0],socEconX[:,3] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,3)
plt.scatter(socEconX[:,0],socEconX[:,3] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,4)
plt.scatter(socEconX[:,0],socEconX[:,4] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,5)
plt.scatter(socEconX[:,0],socEconX[:,5] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,6)
plt.scatter(socEconX[:,1],socEconX[:,2] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,7)
plt.scatter(socEconX[:,1],socEconX[:,3] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,8)
plt.scatter(socEconX[:,1],socEconX[:,4] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,9)
plt.scatter(socEconX[:,1],socEconX[:,5] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,10)
plt.scatter(socEconX[:,2],socEconX[:,3] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,11)
plt.scatter(socEconX[:,2],socEconX[:,4] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,12)
plt.scatter(socEconX[:,2],socEconX[:,5] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,13)
plt.scatter(socEconX[:,3],socEconX[:,4] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,14)
plt.scatter(socEconX[:,3],socEconX[:,5] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.subplot(nrRows,3,15)
plt.scatter(socEconX[:,4],socEconX[:,5] , c=kMeansSocEcon.labels_, cmap='viridis')

plt.show()

# %% [markdown]
# generosity, life expectancy, and GDP per capita

# %%
glegdpCol = ['Economy..GDP.per.Capita.', 'Health..Life.Expectancy.', 'Generosity']

# %%
glegdpX = StandardScaler().fit_transform(df[glegdpCol])

# %%
glegdpKMean= KMeans(n_clusters=nCluster, random_state=0)
glegdpKMean.fit(glegdpX)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,3,1)
plt.scatter(glegdpX[:, 0], glegdpX[:, 1], c=glegdpKMean.labels_, cmap='viridis')
plt.subplot(1,3,2)
plt.scatter(glegdpX[:, 0], glegdpX[:, 2], c=glegdpKMean.labels_, cmap='viridis')
plt.subplot(1,3,3)
plt.scatter(glegdpX[:, 1], glegdpX[:, 2], c=glegdpKMean.labels_, cmap='viridis')
plt.show()

# %% [markdown]
# economic freedom and trust in government

# %%
freeTrustCol = ['Freedom', 'Trust..Government.Corruption.']

# %%
freeTrustX = StandardScaler().fit_transform(df[glegdpCol])

# %%
freeTrustKMean = KMeans(n_clusters=nCluster, random_state=0)
freeTrustKMean.fit(freeTrustX)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(freeTrustX[:, 0], freeTrustX[:, 1], c=freeTrustKMean.labels_, cmap='viridis')
plt.title('KMeans Clustering of Dataset (Standardized)')
plt.show()
